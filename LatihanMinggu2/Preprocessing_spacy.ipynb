# %% [markdown]
# Perbedaan NLTK dan Spacy
# Spacy is better than NLTK in terms of performance.Here, there are some comparison
#
# 1- NLTK is a string processing library. It takes strings as input and returns strings or lists of strings as output.Whereas, spaCy uses object-oriented approach.When we parse a text, spaCy returns document object whose words and sentences are objects themselves.
#
# 2- spaCy has support for word vectors whereas NLTK does not.
#
# 3- In word tokenization and POS-tagging spaCy performs better, but in sentence tokenization, NLTK outperforms spaCy.
#
# 4- NLTK supports various languages whereas spaCy have statistical models for 7 languages (English, German, Spanish, French, Portuguese, Italian, and Dutch). It also supports named entities for multi language.

# %% [markdown]
# NLTK

# %%
# token
import nltk
from nltk.tokenize import word_tokenize 

def word_tokenize_wrapper(text):
  return word_tokenize(text)

# %%
teks_nltk = word_tokenize_wrapper('Yahya beserta teman-teman TK suka melihat lumba-lumba di Batang Dolphin Center')

# %%
teks_nltk
# Out:
# ['Yahya',
#  'beserta',
#  'teman-teman',
#  'TK',
#  'suka',
#  'melihat',
#  'lumba-lumba',
#  'di',
#  'Batang',
#  'Dolphin',
#  'Center']

# %% [markdown]
# spacy
# lakukan installasi dan update lib spacy

# %%
from spacy.lang.id import Indonesian
import spacy

nlp = Indonesian()  # use directly
nlp = spacy.blank('id')  # blank instance'

# %%
Teks = nlp('Yahya beserta teman-teman TK suka melihat lumba-lumba di Batang Dolphin Center')

# %%
Token_kata = [token.text for token in Teks]

# %%
Token_kata
# Out:
# ['Yahya',
#  'beserta',
#  'teman-teman',
#  'TK',
#  'suka',
#  'melihat',
#  'lumba-lumba',
#  'di',
#  'Batang',
#  'Dolphin',
#  'Center']

# %% [markdown]
# load library

# %%
import re
import string
import time
from copy import deepcopy

# %% [markdown]
# load dataset

# %%
import pandas as pd
import json
import os

# %%
file = "2018-01-01/01/00/"

# %%
json_files = [pos_json for pos_json in os.listdir(file) if pos_json.endswith('.json')]

# %%
df = pd.DataFrame(columns=['url', 'date', 'title', 'content'])

# %%
for index, js in enumerate(json_files):
    with open(os.path.join(file, js), encoding="utf-8") as json_file:
        json_text = json.load(json_file)
        url = json_text['url']
        date = json_text['date']
        title = json_text['title']
        content = json_text['content']

        df.loc[index] = [url, date, title, content]

# %%
df
# Out:
#                                                   url                 date  \
# 0   https://www.cnnindonesia.com/ekonomi/201712301...  2018-01-01 00:00:00
# 1   http://khazanah.republika.co.id/berita/dunia-i...  2018-01-01 00:00:00
# 2   https://news.detik.com/berita/d-3793636/selama...  2018-01-01 00:01:00
# 3   https://news.detik.com/berita/d-3793638/jalan-...  2018-01-01 00:01:00
# 4   http://bola.republika.co.id/berita/sepakbola/l...  2018-01-01 00:01:00
# 5   http://nasional.republika.co.id/berita/nasiona...  2018-01-01 00:02:00
# 6   https://news.detik.com/berita/d-3793639/letupa...  2018-01-01 00:04:00
# 7   https://nasional.kompas.com/read/2018/01/01/00...  2018-01-01 00:04:00
# 8   http://nasional.republika.co.id/berita/nasiona...  2018-01-01 00:04:00
# 9   http://poskotanews.com/2018/01/01/tahun-baru-l...  2018-01-01 00:06:00
# 10  https://news.detik.com/berita/d-3793641/dipimp...  2018-01-01 00:10:00
# 11  https://news.detik.com/berita/d-3793640/tahun-...  2018-01-01 00:10:00
# 12  http://internasional.republika.co.id/berita/in...  2018-01-01 00:11:00
# 13  http://nasional.republika.co.id/berita/nasiona...  2018-01-01 00
# 19  Jakarta -\nRaja dangdut yang juga Ketum Partai...
# 20  Banjarnegara -\nAda yang berbeda pada perayaan...
# 21  Bandung -\nDi malam pergantian tahun 2018 ini ...
# 22  Jakarta -\nWarga tumpah ruah di berbagai lokas...
# 23  REPUBLIKA.CO.ID, MELBOURNE -- Larangan minuman...
# 24  Jakarta - Warga DKI Jakarta merayakan tahun ba...
# 25  BANDUNG, KOMPAS.com - Wali Kota Bandung Ridwan...
# 26  Jakarta -\nGubernur DKI Jakarta Anies Baswedan...
# 27  Birmingham - Arsenal berhasil unggul penguasaa...
# 28  DENVER, KOMPAS.com - Sebuah insiden penembakan...
# 29  Jakarta - Perayaan tahun baru 2018 di Bundaran...
# 30  JAKARTA - Pesta kembang api mewarnai kawasan M...
# 31  Cirebon -\nKawasan wisata Gronggong yang berad...
# 32  TEMPO.CO, Jakarta- Wakil Gubernur Sandiaga Uno...
# 33  JAKARTA, KOMPAS.com - Gubernur DKI Jakarta Ani...
# 34  REPUBLIKA.CO.ID, YOGYAKARTA -- Presiden Joko W...
# 35  YOGYAKARTA, KOMPAS.com - Presiden Joko Widodo ...
# 36  TEMPO.CO Jakarta – Jaringan Aktivis Reformasi ...
# 37  REPUBLIKA.CO.ID, LONDON -- Kiper Manchester Ci...
# 38  JAKARTA (Pos Kota) – Hampir saja pasangan ini ...
# 39  REPUBLIKA.CO.ID, SAMARINDA -- East Kalimantan ...
# 40  Yogyakarta -\nTanpa adanya agenda pesta kemban...
# 41  Jakarta -\nGubernur DKI Jakarta Anies Baswedan...
# 42  REPUBLIKA.CO.ID, BANGKOK -- Sebuah keluarga as...
# 43  Medan - Perayaan tahun baru 2018 di Medan, Sum...
# 44  TOKYO - Hiroto Kyoguchi menutup tahun 2017 den...
# 45  REPUBLIKA.CO.ID, KUTA BALI - Wisatawan mancane...
# 46  Yogyakarta -\nAda tiga gadis pemberani asal Ma...
# 47  DENPASAR - Ribuan wisatawan asing dan domestik...
# 48  REPUBLIKA.CO.ID, JAKARTA -- Dinas Lingkungan H...
# 49  magelang -\nRibuan pengunjung Borobudur Nite 2...
# 50  TEMPO.CO Jakarta - Polisi meminta masyarakat m...
# 51  JAKARTA, KOMPAS.com - Gubernur DKI Jakarta Ani...
# 52  Surabaya -\nPergantian tahun di Surabaya berla...
# 53  REPUBLIKA.CO.ID, JAKARTA -- Dalam menyambut pe...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 54 entries, 0 to 53
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    54 non-null     object
#  1   content  54 non-null     object
# dtypes: object(2)
# memory usage: 1.3+ KB

# %% [markdown]
# Preprocessing dataset
#
# kita akan pakai modul dari AMS 01-03
#
# disamping itu kita akan memakai modul https://github.com/cbaziotis/ekphrasis

# %%
from ekphrasis.classes.preprocessor import TextPreProcessor
from ekphrasis.classes.tokenizer import SocialTokenizer
from ekphrasis.dicts.emoticons import emoticons

text_processor = TextPreProcessor(
    # terms that will be normalized
    normalize=['email', 'percent', 'money', 'phone', 'user',
        'time', 'date', 'number'],
    # terms that will be annotated
    #annotate={"hashtag", "allcaps", "elongated", "repeated",'emphasis', 'censored'},
    annotate={"hashtag"},
    fix_html=True,  # fix HTML tokens
    
    # corpus from which the word statistics are going to be used 
    # for word segmentation 
    segmenter="twitter", 
    
    # corpus from which the word statistics are going to be used 
    # for spell correction
    corrector="twitter", 
    
    unpack_hashtags=True,  # perform word segmentation on hashtags
    unpack_contractions=True,  # Unpack contractions (can't -> can not)
    spell_correct_elong=False,  # spell correction for elongated words
    
    # select a tokenizer. You can use SocialTokenizer, or pass your own
    # the tokenizer, should take as input a string and return a list of tokens
    tokenizer=SocialTokenizer(lowercase=True).tokenize,
    
    # list of dictionaries, for replacing tokens extracted from the text,
    # with other expressions. You can pass more than one dictionaries.
    dicts=[emoticons]
)
# Out:
# C:\Users\mmahf\miniconda3\envs\latihanstki\lib\site-packages\ekphrasis\classes\tokenizer.py:225: FutureWarning: Possible nested set at position 2190
#   self.tok = re.compile(r"({})".format("|".join(pipeline)))
# Reading twitter - 1grams ...
# Reading twitter - 2grams ...
# Reading twitter - 1grams ...
# C:\Users\mmahf\miniconda3\envs\latihanstki\lib\site-packages\ekphrasis\classes\exmanager.py:14: FutureWarning: Possible nested set at position 42
#   regexes = {k.lower(): re.compile(self.expressions[k]) for k, v in

# %%
# panggil ekphrasis

def bersih_data(text):
    return " ".join(text_processor.pre_process_doc(text))

# %%
# fungsi dari AMS 01-03. silakan cek bagaimana saya merubah menjadi fungsi

def non_ascii(text):
    return text.encode('ascii', 'replace').decode('ascii')

def remove_space_alzami(text):
    return " ".join(text.split())

def remove_emoji_alzami(text):
    return ' '.join(re.sub("([x#][A-Za-z0-9]+)"," ", text).split())

def remove_tab(text):
    return text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")

def remove_tab2(text):
    return re.sub('\s+',' ',text)

def remove_rt(text):
    return text.replace('rt'," ")

def remove_mention(text):
    return ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())

def remove_incomplete_url(text):
    return text.replace("http://", " ").replace("https://", " ")

def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

def remove_excessive_dot(text):
    return text.replace('..'," ")

def change_stripe(text):
    return text.replace('-'," ")

def lower(text):
    return text.lower()

def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

def remove_excessive_dot(text):
    return text.replace('..'," ")

def lower(text):
    return text.lower()

def remove_whitespace_LT(text):
    return text.strip()

def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

def remove_punctuation(text):
    remove = string.punctuation
    remove = remove.replace("_", "") # don't remove hyphens
    pattern = r"[{}]".format(remove) # create the pattern
    return re.sub(pattern, "", text)

# %%
# hapus untuk <>
def remove_number_eks(text):
    return text.replace('<number>'," ")

def remove_angka(text):
    return re.sub(r"\d+", "", text) 

def remove_URL_eks(text):
    return text.replace('URL'," ").replace('url'," ")

def space_punctuation(text):
    return re.sub('(?<! )(?=[.,!?()])|(?<=[.,!?()])(?! )', r' ', text)

# %% [markdown]
# lakukan pembersihan dengan memanggil fungsi yang didefinisikan diatas

# %%
i = 0
final_string = []
s = ""
for text in df['content'].values:
    filteredSentence = []
    EachReviewText = ""
    proc = lower(text)
    proc = change_stripe(text)
    proc = remove_emoji_alzami(proc)
    proc = remove_tab(proc)
    proc = remove_tab2(proc)
    proc = non_ascii(proc)
    proc = remove_incomplete_url(proc)
    proc = remove_excessive_dot(proc)
    proc = remove_whitespace_LT(proc)
    proc = remove_whitespace_multiple(proc)
    proc = remove_single_char(proc)
    proc = space_punctuation(proc)
    proc = remove_punctuation(proc)
    proc = remove_space_alzami(proc)
    proc = bersih_data(proc)
    #proc = remove_rt(proc)
    proc = remove_number_eks(proc)
    proc = remove_angka(proc) 
    proc = remove_URL_eks(proc)
    EachReviewText = proc
    final_string.append(EachReviewText)

# %%
df["step01"] = final_string

# %%
df.head(10)
# Out:
#                                                title  \
# 0  Geliat Bisnis Sektor Wisata Jelang Pergantian ...
# 1  Dzikir Nasional Siapkan Spiritual untuk Lebih ...
# 2                           Selamat Tahun Baru 2018!
# 3     Jalan-jalan ke Stan OK OCE yang Padati Thamrin
# 4          Allegri: 2017 adalah Tahun Penuh Kepuasan
# 5  Jelang Pergantian Tahun, Jembatan Ampera Ditut...
# 6  Letupan Kembang Api Warnai Tahun Baru 2018 di ...
# 7  Malam Tahun Baru, Jokowi Asyik Temani Cucu Ber...
# 8   Warga Yogya Sambut Jokowi di Titik Nol Kilometer
# 9               Tahun Baru, Langit Jakarta Benderang
#
#                                              content  \
# 0  Jakarta, CNN Indonesia -- Asosiasi Perusahaan ...
# 1  REPUBLIKA.CO.ID, JAKARTA -- Dzikir Nasional 20...
# 2  Jakarta - Warna-warni kembang api di langit Ja...
# 3  Jakarta -\nJalan MH Thamrin malam ini dipadati...
# 4  REPUBLIKA.CO.ID, TURIN — Pelatih Juventus Mass...
# 5  REPUBLIKA.CO.ID, PALEMBANG  -- Jembatan Ampera...
# 6  Jakarta -\nHari ini, Senin dini hari, tepat me...
# 7  YOGYAKARTA, KOMPAS.com - Jelang pergantian tah...
# 8  REPUBLIKA.CO.ID, YOGYAKARTA -- Ribuan warga di...
# 9  JAKARTA (Pos Kota) – Langit Jakarta berpendar ...
#
#                                               step01
# 0  jakarta cnn indonesia asosiasi perusahaan perj...
# 1  republika co id jakarta dzikir nasional   bert...
# 2  jakarta warna warni kembang api di langit jaka...
# 3  jakarta jalan mh thamrin malam ini dipadati pe...
# 4  republika co id turin pelatih juventus massimi...
# 5  republika co id palembang jembatan ampera pale...
# 6  jakarta hari ini senin dini hari tepat memasuk...
# 7  yogyakarta kompas com jelang pergantian tahun ...
# 8  republika co id yogyakarta ribuan warga di kaw...
# 9  jakarta pos kota langit jakarta berpendar warn...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 54 entries, 0 to 53
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    54 non-null     object
#  1   content  54 non-null     object
#  2   step01   54 non-null     object
# dtypes: object(3)
# memory usage: 1.7+ KB

# %%
df_hapus = df[~df['step01'].str.contains(" ")]

# %%
df_hapus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    0 non-null      object
#  1   content  0 non-null      object
#  2   step01   0 non-null      object
# dtypes: object(3)
# memory usage: 0.0+ bytes

# %%
df_hapus.head(10)
# Out:
# Empty DataFrame
# Columns: [title, content, step01]
# Index: []

# %%
df_new = df[~df.isin(df_hapus)].dropna()

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 54 entries, 0 to 53
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    54 non-null     object
#  1   content  54 non-null     object
#  2   step01   54 non-null     object
# dtypes: object(3)
# memory usage: 1.7+ KB

# %%
df_new
# Out:
#                                                 title  \
# 0   Geliat Bisnis Sektor Wisata Jelang Pergantian ...
# 1   Dzikir Nasional Siapkan Spiritual untuk Lebih ...
# 2                            Selamat Tahun Baru 2018!
# 3      Jalan-jalan ke Stan OK OCE yang Padati Thamrin
# 4           Allegri: 2017 adalah Tahun Penuh Kepuasan
# 5   Jelang Pergantian Tahun, Jembatan Ampera Ditut...
# 6   Letupan Kembang Api Warnai Tahun Baru 2018 di ...
# 7   Malam Tahun Baru, Jokowi Asyik Temani Cucu Ber...
# 8    Warga Yogya Sambut Jokowi di Titik Nol Kilometer
# 9                Tahun Baru, Langit Jakarta Benderang
# 10  Dipimpin Sandiaga, Pesta Kembang Api Tandai Pe...
# 11        Tahun Baru 2018, Anies Pukul Beduk di Monas
# 12  Pemerintah Iran Diminta Penuhi Tuntutan Demons...
# 13                Solo Musnahkan Jutaan Butir Pil PCC
# 14        Kimura Akhiri 2017 dengan Catatan Fenomenal
# 15  Jelang Pergantian Tahun, Jokowi Sapa Masyaraka...
# 16                      Surat Akhir Tahun Sri Mulyani
# 17  Asyik, Ada Nasi Goreng Gratis Buatan Brimob di...
# 18  Merasakan Kemeriahan Perayaan Tahun Baru di Ka...
# 19  Rhoma Irama: Jangan Lagi ada Ahoker-Anieser, S...
# 20  Tahun Baru di Banjarnegara, Bupati Wing Chien ...
# 21  Sambut Tahun Baru, Ridwan Kamil Resmikan Alun-...
# 22  Anies Ingatkan Warga Bersihkan Sampah Usai Per...
# 23  Sampah Menumpuk, Larangan Alkohol Pantai Ini D...
# 24  Rayakan Tahun Baru, Sirine Mobil Pemadam Dibun...
# 25  Malam Tahun Baru, Ridwan Kamil Resmikan Alun-a...
# 26  Anies ke Balai Kota Usai Rayakan Tahun Baru 20...
# 12  republika co id istanbul wakil ketua parlemen ...
# 13  republika co id solo kepolisian daerah jawa te...
# 14  tokyo petinju asal jepang yang sebelum tidak b...
# 15  republika co id yogyakarta presiden joko widod...
# 16  jakarta tahun   berlalu dan berganti dengan ta...
# 17  bandung ada yang berbeda saat malam pergantian...
# 18  yogyakarta kompas com kawasan malioboro yogyak...
# 19  jakarta raja dangdut yang juga ketum partai id...
# 20  banjarnegara ada yang berbeda pada perayaan ta...
# 21  bandung di malam pergantian tahun   ini wali k...
# 22  jakarta warga tumpah ruah di berbagai lokasi d...
# 23  republika co id melbourne larangan minuman ber...
# 24  jakarta warga dki jakarta merayakan tahun baru...
# 25  bandung kompas com wali kota bandung ridwan ka...
# 26  jakarta gubernur dki jakarta anies baswedan se...
# 27  birmingham arsenal berhasil unggul penguasaan ...
# 28  denver kompas com sebuah insiden penembakan te...
# 29  jakarta perayaan tahun baru   di bundaran hi s...
# 30  jakarta pesta kembang api mewarnai kawasan mon...
# 31  cirebon kawasan wisata gronggong yang berada d...
# 32  tempo co jakarta wakil gubernur sandiaga uno b...
# 33  jakarta kompas com gubernur dki jakarta anies ...
# 34  republika co id yogyakarta presiden joko widod...
# 35  yogyakarta kompas com presiden joko widodo men...
# 36  tempo co jakarta jaringan aktivis reformasi   ...
# 37  republika co id london kiper manchester city e...
# 38  jakarta pos kota hampir saja pasangan ini gaga...
# 39  republika co id samarinda east kalimantan reco...
# 40  yogyakarta tanpa adanya agenda pesta kembang a...
# 41  jakarta gubernur dki jakarta anies baswedan me...
# 42  republika co id bangkok sebuah keluarga asal z...
# 43  medan perayaan tahun baru   di medan sumatera ...
# 44  tokyo hiroto kyoguchi menutup tahun   dengan k...
# 45  republika co id kuta bali wisatawan mancanegar...
# 46  yogyakarta ada tiga gadis pemberani asal madiu...
# 47  denpasar ribuan wisatawan asing dan domestik n...
# 48  republika co id jakarta dinas lingkungan hidup...
# 49  magelang ribuan pengunjung borobudur nite   be...
# 50  tempo co jakarta polisi meminta masyarakat mem...
# 51  jakarta kompas com gubernur dki jakarta anies ...
# 52  surabaya pergantian tahun di surabaya berlangs...
# 53  republika co id jakarta dalam menyambut pergan...

# %% [markdown]
# normalisasi kata slang menjadi kata baku

# %%
# token
import nltk
from nltk.tokenize import word_tokenize

# %%
def word_tokenize_wrapper(text):
  return word_tokenize(text)

# %%
df_new['tokens'] = df['step01'].apply(word_tokenize_wrapper)

# %%
df_new.head(10)
# Out:
#                                                title  \
# 0  Geliat Bisnis Sektor Wisata Jelang Pergantian ...
# 1  Dzikir Nasional Siapkan Spiritual untuk Lebih ...
# 2                           Selamat Tahun Baru 2018!
# 3     Jalan-jalan ke Stan OK OCE yang Padati Thamrin
# 4          Allegri: 2017 adalah Tahun Penuh Kepuasan
# 5  Jelang Pergantian Tahun, Jembatan Ampera Ditut...
# 6  Letupan Kembang Api Warnai Tahun Baru 2018 di ...
# 7  Malam Tahun Baru, Jokowi Asyik Temani Cucu Ber...
# 8   Warga Yogya Sambut Jokowi di Titik Nol Kilometer
# 9               Tahun Baru, Langit Jakarta Benderang
#
#                                              content  \
# 0  Jakarta, CNN Indonesia -- Asosiasi Perusahaan ...
# 1  REPUBLIKA.CO.ID, JAKARTA -- Dzikir Nasional 20...
# 2  Jakarta - Warna-warni kembang api di langit Ja...
# 3  Jakarta -\nJalan MH Thamrin malam ini dipadati...
# 4  REPUBLIKA.CO.ID, TURIN — Pelatih Juventus Mass...
# 5  REPUBLIKA.CO.ID, PALEMBANG  -- Jembatan Ampera...
# 6  Jakarta -\nHari ini, Senin dini hari, tepat me...
# 7  YOGYAKARTA, KOMPAS.com - Jelang pergantian tah...
# 8  REPUBLIKA.CO.ID, YOGYAKARTA -- Ribuan warga di...
# 9  JAKARTA (Pos Kota) – Langit Jakarta berpendar ...
#
#                                               step01  \
# 0  jakarta cnn indonesia asosiasi perusahaan perj...
# 1  republika co id jakarta dzikir nasional   bert...
# 2  jakarta warna warni kembang api di langit jaka...
# 3  jakarta jalan mh thamrin malam ini dipadati pe...
# 4  republika co id turin pelatih juventus massimi...
# 5  republika co id palembang jembatan ampera pale...
# 6  jakarta hari ini senin dini hari tepat memasuk...
# 7  yogyakarta kompas com jelang pergantian tahun ...
# 8  republika co id yogyakarta ribuan warga di kaw...
# 9  jakarta pos kota langit jakarta berpendar warn...
#
#                                               tokens
# 0  [jakarta, cnn, indonesia, asosiasi, perusahaan...
# 1  [republika, co, id, jakarta, dzikir, nasional,...
# 2  [jakarta, warna, warni, kembang, api, di, lang...
# 3  [jakarta, jalan, mh, thamrin, malam, ini, dipa...
# 4  [republika, co, id, turin, pelatih, juventus, ...
# 5  [republika, co, id, palembang, jembatan, amper...
# 6  [jakarta, hari, ini, senin, dini, hari, tepat,...
# 7  [yogyakarta, kompas, com, jelang, pergantian, ...
# 8  [republika, co, id, yogyakarta, ribuan, warga,...
# 9  [jakarta, pos, kota, langit, jakarta, berpenda...

# %%
normalized_word = pd.read_csv('kamus_clean.csv')

# %%
normalized_word_dict = {}

for index, row in normalized_word.iterrows():
    if row[0] not in normalized_word_dict:
        normalized_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalized_word_dict[term] if term in normalized_word_dict else term for term in document]
# Out:
# C:\Users\mmahf\AppData\Local\Temp\ipykernel_28472\2408214049.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] not in normalized_word_dict:
# C:\Users\mmahf\AppData\Local\Temp\ipykernel_28472\2408214049.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   normalized_word_dict[row[0]] = row[1]

# %%
df_new['final_tokens'] = df_new['tokens'].apply(normalized_term)

# %%
i=0
final_string_tokens = []
for text in df_new['final_tokens'].values:
    EachReviewText = ""
    EachReviewText = ' '.join(text)
    final_string_tokens.append(EachReviewText)

# %%
df_new["step02"] = final_string_tokens

# %%
df_new.head(10)
# Out:
#                                                title  \
# 0  Geliat Bisnis Sektor Wisata Jelang Pergantian ...
# 1  Dzikir Nasional Siapkan Spiritual untuk Lebih ...
# 2                           Selamat Tahun Baru 2018!
# 3     Jalan-jalan ke Stan OK OCE yang Padati Thamrin
# 4          Allegri: 2017 adalah Tahun Penuh Kepuasan
# 5  Jelang Pergantian Tahun, Jembatan Ampera Ditut...
# 6  Letupan Kembang Api Warnai Tahun Baru 2018 di ...
# 7  Malam Tahun Baru, Jokowi Asyik Temani Cucu Ber...
# 8   Warga Yogya Sambut Jokowi di Titik Nol Kilometer
# 9               Tahun Baru, Langit Jakarta Benderang
#
#                                              content  \
# 0  Jakarta, CNN Indonesia -- Asosiasi Perusahaan ...
# 1  REPUBLIKA.CO.ID, JAKARTA -- Dzikir Nasional 20...
# 2  Jakarta - Warna-warni kembang api di langit Ja...
# 3  Jakarta -\nJalan MH Thamrin malam ini dipadati...
# 4  REPUBLIKA.CO.ID, TURIN — Pelatih Juventus Mass...
# 5  REPUBLIKA.CO.ID, PALEMBANG  -- Jembatan Ampera...
# 6  Jakarta -\nHari ini, Senin dini hari, tepat me...
# 7  YOGYAKARTA, KOMPAS.com - Jelang pergantian tah...
# 8  REPUBLIKA.CO.ID, YOGYAKARTA -- Ribuan warga di...
# 9  JAKARTA (Pos Kota) – Langit Jakarta berpendar ...
#
#                                               step01  \
# 0  jakarta cnn indonesia asosiasi perusahaan perj...
# 1  republika co id jakarta dzikir nasional   bert...
# 2  jakarta warna warni kembang api di langit jaka...
# 3  jakarta jalan mh thamrin malam ini dipadati pe...
# 4  republika co id turin pelatih juventus massimi...
# 5  republika co id palembang jembatan ampera pale...
# 6  jakarta hari ini senin dini hari tepat memasuk...
# 7  yogyakarta kompas com jelang pergantian tahun ...
# 8  republika co id yogyakarta ribuan warga di kaw...
# 9  jakarta pos kota langit jakarta berpendar warn...
#
#                                               tokens  \
# 0  [jakarta, cnn, indonesia, asosiasi, perusahaan...
# 1  [republika, co, id, jakarta, dzikir, nasional,...
# 2  [jakarta, warna, warni, kembang, api, di, lang...
# 3  [jakarta, jalan, mh, thamrin, malam, ini, dipa...
# 4  [republika, co, id, turin, pelatih, juventus, ...
# 5  [republika, co, id, palembang, jembatan, amper...
# 6  [jakarta, hari, ini, senin, dini, hari, tepat,...
# 7  [yogyakarta, kompas, com, jelang, pergantian, ...
# 8  [republika, co, id, yogyakarta, ribuan, warga,...
# 9  [jakarta, pos, kota, langit, jakarta, berpenda...
#
#                                         final_tokens  \
# 0  [jakarta, cnn, indonesia, asosiasi, perusahaan...
# 1  [republika, co, id, jakarta, dzikir, nasional,...
# 2  [jakarta, warna, warni, kembang, api, di, lang...
# 3  [jakarta, jalan, mh, thamrin, malam, ini, dipa...
# 4  [republika, co, id, turin, pelatih, juventus, ...
# 5  [republika, co, id, palembang, jembatan, amper...
# 6  [jakarta, hari, ini, senin, dini, hari, tepat,...
# 7  [yogyakarta, kompas, com, jelang, pergantian, ...
# 8  [republika, co, id, yogyakarta, ribuan, warga,...
# 9  [jakarta, pos, kota, langit, jakarta, berpenda...
#
#                                               step02
# 0  jakarta cnn indonesia asosiasi perusahaan perj...
# 1  republika co id jakarta dzikir nasional bertuj...
# 2  jakarta warna warni kembang api di langit jaka...
# 3  jakarta jalan mh thamrin malam ini dipadati pe...
# 4  republika co id turin pelatih juventus massimi...
# 5  republika co id palembang jembatan ampera pale...
# 6  jakarta hari ini senin dini hari tepat memasuk...
# 7  yogyakarta kompas com jelang pergantian tahun ...
# 8  republika co id yogyakarta ribuan warga di kaw...
# 9  jakarta pos kota langit jakarta berpendar warn...

# %%
df.to_csv('clean_dataset2.csv',sep=";")
